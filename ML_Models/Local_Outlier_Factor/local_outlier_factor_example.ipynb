# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import LocalOutlierFactor


rng = np.random.RandomState(42)
X_inliers = 0.3 * rng.randn(300, 2) + np.array([2, 2])
X_outliers = rng.uniform(low=-4, high=6, size=(15, 2))
X = np.r_[X_inliers, X_outliers]

# %%
lof = LocalOutlierFactor(n_neighbors=20, contamination=0.05)  # adjust as needed
y_pred = lof.fit_predict(X)   # -1 = outlier, 1 = inlier
scores = -lof.negative_outlier_factor_  # higher = more anomalous

# %%
plt.figure(figsize=(6, 5))
plt.scatter(X[y_pred == 1, 0], X[y_pred == 1, 1], s=25, label="Inliers")
plt.scatter(X[y_pred == -1, 0], X[y_pred == -1, 1], s=40, edgecolors="r", facecolors="none", label="Outliers")
plt.title("Local Outlier Factor (LOF) – Unsupervised")
plt.legend()
plt.tight_layout()
plt.show()
